# %%
import yfinance as yf
from datetime import datetime
import pandas as pd
import psycopg2
import configparser
import datetime
import nbimporter
from General import *
from Daily_etl import *
from SQL import *
from Functions import *
from PerdictiveModel1 import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 8
#       6 import datetime
#       7 import nbimporter
# ----> 8 from General import *
#       9 from Daily_etl import *
#      10 from SQL import *
#
# File ~/anaconda3/lib/python3.11/site-packages/nbimporter.py:110, in NotebookLoader.load_module(self, fullname)
#     108         # run the code in the module
#     109         codeobj = compile(tree, filename=path, mode='exec')
# --> 110         exec(codeobj, mod.__dict__)
#     111 finally:
#     112     self.shell.user_ns = save_user_ns
#
# File ~/Desktop/Final Year project Python/General.ipynb:8
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 13,
#       6    "id": "2c924f7c-8199-4a4c-b1d9-d6e756bf022e",
#       7    "metadata": {
# ----> 8     "tags": []
#       9    },
#      10    "outputs": [],
#      11    "source": [
#      12     "import yfinance as yf\n",
#      13     "from datetime import datetime\n",
#      14     "import pandas as pd\n",
#      15     "import psycopg2\n",
#      16     "import configparser\n",
#      17     "import datetime\n",
#      18     "import nbimporter\n",
#      19     "from Functions import *\n",
#      20     "from Daily_etl import *\n",
#      21     "from SQL import *\n",
#      22     "from Connection_to_pgAdmin4 import *"
#      23    ]
#      24   },
#      25   {
#      26    "cell_type": "code",
#      27    "execution_count": 9,
#      28    "id": "2fd8c68d-e797-4c80-8023-d61c49c08e5d",
#      29    "metadata": {
#      30     "tags": []
#      31    },
#      32    "outputs": [
#      33     {
#      34      "data": {
#      35       "text/plain": [
#      36        "'pip install psycopg2'"
#      37       ]
#      38      },
#      39      "execution_count": 9,
#      40      "metadata": {},
#      41      "output_type": "execute_result"
#      42     }
#      43    ],
#      44    "source": [
#      45     "#installation \n",
#      46     "#by default you might not have yahoo finance/ library, or psycopg2, or  nbimporternbimporter so you may have to install one\n",
#      47     "'''pip install yfinance'''\n",
#      48     "'''pip install nbimporter'''\n",
#      49     "'''pip install psycopg2'''\n"
#      50    ]
#      51   },
#      52   {
#      53    "cell_type": "code",
#      54    "execution_count": 20,
#      55    "id": "6dda4cb3-bf87-4950-9c72-a540be8a1642",
#      56    "metadata": {
#      57     "tags": []
#      58    },
#      59    "outputs": [
#      60     {
#      61      "data": {
#      62       "text/plain": [
#      63        "\"\\nsource = 'Source'\\nstaging='Staging'\\ndimensions='Dimension'\\nfacts='Facts\\n\""
#      64       ]
#      65      },
#      66      "execution_count": 20,
#      67      "metadata": {},
#      68      "output_type": "execute_result"
#      69     }
#      70    ],
#      71    "source": [
#      72     "#schema variables \n",
#      73     "#defining these as they will be used for development of sql queries\n",
#      74     "#source = 'Source'\n",
#      75     "#staging='Staging'\n",
#      76     "#dimensions='Dimension'\n",
#      77     "#facts='Facts"
#      78    ]
#      79   },
#      80   {
#      81    "cell_type": "code",
#      82    "execution_count": 13,
#      83    "id": "24d61c10-4e47-4082-bf1a-89d9c6a38b06",
#      84    "metadata": {
#      85     "tags": []
#      86    },
#      87    "outputs": [],
#      88    "source": [
#      89     "#This is a sample test and will be used for testing only. \n",
#      90     "#It utilises yfinance library. It takes \"Ticker\" symbol then returns the ticker information. \n",
#      91     "#Fetch data for a single stock symbol\n",
#      92     "#This is used to get financial information on stock market from yahoo finance using ticker as test \n",
#      93     "\n",
#      94     "stock = yf.Ticker(\"AAPL\")\n",
#      95     "hist = stock.history(period=\"25y\")  # Fetches one month of historical data\n",
#      96     "\n",
#      97     "#print(hist)\n",
#      98     "#If you want to see the result just uncomment the print statement.\n",
#      99     "#This was a test that was run to ensure that the code is able to work on one ticker\n"
#     100    ]
#     101   },
#     102   {
#     103    "cell_type": "code",
#     104    "execution_count": 15,
#     105    "id": "b86225a9-742f-4789-9414-307d87c46977",
#     106    "metadata": {
#     107     "tags": []
#     108    },
#     109    "outputs": [
#     110     {
#     111      "data": {
#     112       "text/plain": [
#     113        "'\\nIn order to get the data into postgreSQL database there are steps that i am following \\n\\n1 In order to download information on a company I will need their ticker name. \\n\\nFor example company like APPLE their ticker symbol would be AAPL. Their ticker name will be used to feth data based on them. The same applies to the rest of the companies on LSEG. \\n\\nThe code developed below will use ticker symbol to fetch data per company. Because there is yfinance library available that will help with downloading historical data , \\nI will utilise that by using ticker symbol per company, Therefor it is important to use ticker symbol to extract a companies historical data.\\n\\nThere is a file downloaded from https://www.eoddata.com/stockquote/LSE/FEUI.html and an account is required to obtain it.\\nThis file holds information on companies and their tickers.\\nThis is technically easier as there will be less time spent trying to obtain ticker name from stock market.\\n\\n\\n**************************\\nNeed this to go into log book\\n'"
#     114       ]
#     115      },
#     116      "execution_count": 15,
#     117      "metadata": {},
#     118      "output_type": "execute_result"
#     119     }
#     120    ],
#     121    "source": [
#     122     "'''\n",
#     123     "In order to get the data into postgreSQL database there are steps that i am following \n",
#     124     "\n",
#     125     "1 In order to download information on a company I will need their ticker name. \n",
#     126     "\n",
#     127     "For example company like APPLE their ticker symbol would be AAPL. Their ticker name will be used to feth data based on them. The same applies to the rest of the companies on LSEG. \n",
#     128     "\n",
#     129     "The code developed below will use ticker symbol to fetch data per company. Because there is yfinance library available that will help with downloading historical data , \n",
#     130     "I will utilise that by using ticker symbol per company, Therefor it is important to use ticker symbol to extract a companies historical data.\n",
#     131     "\n",
#     132     "There is a file downloaded from https://www.eoddata.com/stockquote/LSE/FEUI.html and an account is required to obtain it.\n",
#     133     "This file holds information on companies and their tickers.\n",
#     134     "This is technically easier as there will be less time spent trying to obtain ticker name from stock market.\n",
#     135     "\n",
#     136     "\n",
#     137     "**************************\n",
#     138     "Need this to go into log book\n",
#     139     "'''\n",
#     140     "\n"
#     141    ]
#     142   },
#     143   {
#     144    "cell_type": "code",
#     145    "execution_count": 10,
#     146    "id": "b3137d5d-d21b-49b1-91dc-4ea92990d789",
#     147    "metadata": {
#     148     "tags": []
#     149    },
#     150    "outputs": [],
#     151    "source": [
#     152     "\n",
#     153     "\n",
#     154     "#Moving data from file to the database\n",
#     155     "#I have now downloaded a file from https://www.eoddata.com/stockquote/LSE/FEUI.html \n",
#     156     "#The file contains information on tickers and symbols. \n",
#     157     "#I will now pushed information from the file into database.\n",
#     158     "\n",
#     159     "\n"
#     160    ]
#     161   },
#     162   {
#     163    "cell_type": "code",
#     164    "execution_count": 21,
#     165    "id": "ef7430a7-40c3-4d62-87ec-204ad31d7c1f",
#     166    "metadata": {},
#     167    "outputs": [
#     168     {
#     169      "data": {
#     170       "text/plain": [
#     171        "'\\n#*******\\n\\n\\n#path to the text file \\nfile_path = \"lse.txt\"\\n\\n#SQL query to insert data into the table\\ninsert_query = \"\"\"\\nINSERT INTO source.ticker_and_name (symbol, Description)\\nVALUES (%s, %s);\\n\"\"\"\\n\\n#connection to the database and creates a cursor\\nconnection = connect_to_database()\\ncursor = connection.cursor()\\n\\ntry:\\n    # Opens the file for reading\\n    with open(file_path, \"r\") as file:\\n        # Reads each line in the file\\n        for line in file:\\n            # Splits each line into columns based on a delimiter (e.g., tab)\\n            parts = line.strip().split(\\'\\t\\')  # Assumes tab as the delimiter\\n\\n            # Check if the line contains the expected number of columns\\n            if len(parts) == 2:  # Assuming 2 columns (Symbol and Description)\\n                symbol, description = parts\\n\\n                # Executes the INSERT query for each row\\n                cursor.execute(insert_query, (symbol, description))\\n\\n    # Commits the changes to the database\\n    connection.commit()\\n    print(\"Data inserted successfully.\")\\n\\nexcept (Exception, psycopg2.Error) as error:\\n    print(f\"Error: {error}\")\\n    if connection:\\n        connection.rollback()\\n\\nfinally:\\n    # Closes the cursor and connection\\n    if cursor:\\n        cursor.close()\\n    if connection:\\n        connection.close()\\n\\n#*******\\n'"
#     172       ]
#     173      },
#     174      "execution_count": 21,
#     175      "metadata": {},
#     176      "output_type": "execute_result"
#     177     }
#     178    ],
#     179    "source": [
#     180     "#Insert data into the table from text file so this can used at a later stage.\n",
#     181     "#This is being stored in a table so that it can be kept for records. \n",
#     182     "#This will also aid in data transformation\n",
#     183     "\n",
#     184     "#this code will be commented out so incase if run by mistake it does not cause duplications, or rewrites the same table and you may lose data.\n",
#     185     "#You will need to remove the ******* and uncomment the code. \n",
#     186     "#SQL REFERENCE \n",
#     187     "##Reference cell\n",
#     188     "\n",
#     189     "\n",
#     190     "'''\n",
#     191     "#*******\n",
#     192     "\n",
#     193     "\n",
#     194     "#path to the text file \n",
#     195     "file_path = \"lse.txt\"\n",
#     196     "\n",
#     197     "#SQL query to insert data into the table\n",
#     198     "insert_query = \"\"\"\n",
#     199     "INSERT INTO source.ticker_and_name (symbol, Description)\n",
#     200     "VALUES (%s, %s);\n",
#     201     "\"\"\"\n",
#     202     "\n",
#     203     "#connection to the database and creates a cursor\n",
#     204     "connection = connect_to_database()\n",
#     205     "cursor = connection.cursor()\n",
#     206     "\n",
#     207     "try:\n",
#     208     "    # Opens the file for reading\n",
#     209     "    with open(file_path, \"r\") as file:\n",
#     210     "        # Reads each line in the file\n",
#     211     "        for line in file:\n",
#     212     "            # Splits each line into columns based on a delimiter (e.g., tab)\n",
#     213     "            parts = line.strip().split('\\t')  # Assumes tab as the delimiter\n",
#     214     "\n",
#     215     "            # Check if the line contains the expected number of columns\n",
#     216     "            if len(parts) == 2:  # Assuming 2 columns (Symbol and Description)\n",
#     217     "                symbol, description = parts\n",
#     218     "\n",
#     219     "                # Executes the INSERT query for each row\n",
#     220     "                cursor.execute(insert_query, (symbol, description))\n",
#     221     "\n",
#     222     "    # Commits the changes to the database\n",
#     223     "    connection.commit()\n",
#     224     "    print(\"Data inserted successfully.\")\n",
#     225     "\n",
#     226     "except (Exception, psycopg2.Error) as error:\n",
#     227     "    print(f\"Error: {error}\")\n",
#     228     "    if connection:\n",
#     229     "        connection.rollback()\n",
#     230     "\n",
#     231     "finally:\n",
#     232     "    # Closes the cursor and connection\n",
#     233     "    if cursor:\n",
#     234     "        cursor.close()\n",
#     235     "    if connection:\n",
#     236     "        connection.close()\n",
#     237     "\n",
#     238     "#*******\n",
#     239     "'''\n",
#     240     "\n",
#     241     "\n",
#     242     "#Now that ticker is saved one test will be run below to see what data it holds and get the sape of it."
#     243    ]
#     244   },
#     245   {
#     246    "cell_type": "code",
#     247    "execution_count": null,
#     248    "id": "2c8e4634-255b-433d-a8bd-f147c6dfc706",
#     249    "metadata": {},
#     250    "outputs": [],
#     251    "source": [
#     252     "\n",
#     253     "#Now that I have ticker and desription of the companies, i will test the sybmols by giving it to yfinance library to fetch infotmation on in.\n",
#     254     "#Below is an example of the ticker AAPL\n"
#     255    ]
#     256   },
#     257   {
#     258    "cell_type": "code",
#     259    "execution_count": 4,
#     260    "id": "a509a6d1-d506-4ca3-8e38-98287e0d413a",
#     261    "metadata": {
#     262     "tags": []
#     263    },
#     264    "outputs": [
#     265     {
#     266      "name": "stdout",
#     267      "output_type": "stream",
#     268      "text": [
#     269       "Metadata for AAPL\n",
#     270       "Name: Apple Inc.\n",
#     271       "Industry: Consumer Electronics\n",
#     272       "Sector: Technology\n",
#     273       "Country: United States\n",
#     274       "Market Cap: 2787957800960\n"
#     275      ]
#     276     }
#     277    ],
#     278    "source": [
#     279     "#The code below just gets the shape of the metadata on company\n",
#     280     "\n",
#     281     "\n",
#     282     "# Create a Ticker object for the symbol you want to get metadata for\n",
#     283     "symbol = \"AAPL\"  # Replace with the symbol you're interested in\n",
#     284     "ticker = yf.Ticker(symbol)\n",
#     285     "\n",
#     286     "# Access the metadata attributes\n",
#     287     "metadata = ticker.info\n",
#     288     "\n",
#     289     "\n",
#     290     "\n",
#     291     "#***************** \n",
#     292     "#more can be printed by removing the comment from the print statament below.\n",
#     293     "#print (metadata)\n",
#     294     "print(\"Metadata for\", symbol)\n",
#     295     "print(\"Name:\", metadata[\"shortName\"])\n",
#     296     "print(\"Industry:\", metadata[\"industry\"])\n",
#     297     "print(\"Sector:\", metadata[\"sector\"])\n",
#     298     "print(\"Country:\", metadata[\"country\"])\n",
#     299     "print(\"Market Cap:\", metadata[\"marketCap\"])\n"
#     300    ]
#     301   },
#     302   {
#     303    "cell_type": "code",
#     304    "execution_count": null,
#     305    "id": "da1191c0-438a-4205-81fa-d92ac23544cc",
#     306    "metadata": {},
#     307    "outputs": [],
#     308    "source": [
#     309     "#***********\n",
#     310     "\n",
#     311     "#Now from the previous test I can get information on tickers I now need to create a table that will hold the information on finance of the companies.\n",
#     312     "#Below SQL creats a table in the source schema\n"
#     313    ]
#     314   },
#     315   {
#     316    "cell_type": "code",
#     317    "execution_count": null,
#     318    "id": "898dca04-1adc-4c0a-b59c-80660f8bead7",
#     319    "metadata": {},
#     320    "outputs": [],
#     321    "source": [
#     322     "#***********\n",
#     323     "\n",
#     324     "#Now using the information provided by the yfinance library, I will use ticker.history method to call each ticker, and store their information on table that was created above. \n",
#     325     "#Below is a function that will be used to fetch data from the yfinance library, because there are so manu columns that I do not need, I will limit the number of columns to fetch too.\n"
#     326    ]
#     327   },
#     328   {
#     329    "cell_type": "code",
#     330    "execution_count": 18,
#     331    "id": "c85e5220-46c7-47e6-a131-67dcd32eb220",
#     332    "metadata": {
#     333     "tags": []
#     334    },
#     335    "outputs": [],
#     336    "source": [
#     337     "#Taking each symbole from the lse.txt file that was downloaded earlier, \n",
#     338     "#looping through 1st 100 in the list at a time and fetching records from yahoo finance yfinance library from 2005\n",
#     339     "#path to file containing symbols\n",
#     340     "#Read and process the file\n",
#     341     " \n",
#     342     "'''\n",
#     343     "It will first read the file\n",
#     344     "and stores the sybmols inside an empty array. \n",
#     345     "\n",
#     346     "ensuring the that there are no nulls, or integar values. \n",
#     347     "\n",
#     348     "using the stored symbols get companies information since 2005 till today. \n",
#     349     "\n",
#     350     "Once records are fetched Then inserting into the table created above\n",
#     351     "\n",
#     352     "In order to mange hitting the api limits for yfinance library I had to complete this task in batch of a hundred.\n",
#     353     "\n",
#     354     "'''\n"
#     355    ]
#     356   },
#     357   {
#     358    "cell_type": "code",
#     359    "execution_count": 22,
#     360    "id": "c0ebc64d-0600-49b1-b0f4-9a6d8e40776b",
#     361    "metadata": {},
#     362    "outputs": [
#     363     {
#     364      "data": {
#     365       "text/plain": [
#     366        "'\\n# Path to file containing symbols\\nfile_path = \"lse.txt\"\\nsymbols = []\\n\\n# Flag to start adding symbols after finding \"02NG.L\"\\nstart_adding = False\\n\\nwith open(file_path, \"r\") as file:\\n    next(file)  # Skip the header\\n    for line in file:\\n        symbol = line.split()[0].strip()\\n        # Skip invalid symbols\\n        if symbol in (\\'null\\', \\'0.0\\', \\'\\'):\\n            continue\\n        if symbol == \"02NG.L\":\\n            start_adding = True\\n        if start_adding:\\n            symbols.append(symbol)\\n\\n#SQL INSERT statement here\\ninsert_query = \"\"\"\\n    INSERT INTO source.historical_stock_data (Date, Open, High, Low, Close, Volume, Dividends, Stock_Splits, Symbol)\\n    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)\\n\"\"\"\\n\\n# Process symbols in batches of 100\\nbatch_size = 100\\nfor i in range(0, len(symbols), batch_size):\\n    batch_symbols = symbols[i:i + batch_size]\\n    all_historical_data = pd.DataFrame()\\n\\n    for symbol in batch_symbols:\\n        historical_data = fetch_historical_data(symbol)\\n        if not historical_data.empty:\\n            all_historical_data = pd.concat([all_historical_data, historical_data])\\n\\n    if not all_historical_data.empty:\\n        records_to_insert = all_historical_data.to_records(index=False).tolist()\\n\\n        record_count = 0\\n        for record in records_to_insert:\\n            # Handle NaN values and convert them to None\\n            modified_record = tuple([None if pd.isna(value) else value for value in record])\\n\\n            execute_sql_query(insert_query, modified_record)\\n            record_count += 1\\n\\n        print(f\"Batch {i//batch_size + 1}: Inserted {record_count} records.\")\\n    else:\\n        print(f\"Batch {i//batch_size + 1}: No data to insert.\")\\n        \\n'"
#     367       ]
#     368      },
#     369      "execution_count": 22,
#     370      "metadata": {},
#     371      "output_type": "execute_result"
#     372     }
#     373    ],
#     374    "source": [
#     375     "#*********************\n",
#     376     "#WARNING IF YOU RUN THIS CODE IT WILL START POPULATING THE DATABASE THAT WILL RUN FOR FEW DAYS ENSURE YOU HAVE THE RIGHT SPACE AND ENVIRONMENT  \n",
#     377     "#AND ENSURE THIS CODE REMAIN COMMENTED.\n",
#     378     "#Functions used \n",
#     379     "#SQL REFERENCE A\n",
#     380     "##Reference cell A\n",
#     381     "#*********************\n",
#     382     "\n",
#     383     "\n",
#     384     "\n",
#     385     "\n",
#     386     "'''\n",
#     387     "# Path to file containing symbols\n",
#     388     "file_path = \"lse.txt\"\n",
#     389     "symbols = []\n",
#     390     "\n",
#     391     "# Flag to start adding symbols after finding \"02NG.L\"\n",
#     392     "start_adding = False\n",
#     393     "\n",
#     394     "with open(file_path, \"r\") as file:\n",
#     395     "    next(file)  # Skip the header\n",
#     396     "    for line in file:\n",
#     397     "        symbol = line.split()[0].strip()\n",
#     398     "        # Skip invalid symbols\n",
#     399     "        if symbol in ('null', '0.0', ''):\n",
#     400     "            continue\n",
#     401     "        if symbol == \"02NG.L\":\n",
#     402     "            start_adding = True\n",
#     403     "        if start_adding:\n",
#     404     "            symbols.append(symbol)\n",
#     405     "\n",
#     406     "#SQL INSERT statement here\n",
#     407     "insert_query = \"\"\"\n",
#     408     "    INSERT INTO source.historical_stock_data (Date, Open, High, Low, Close, Volume, Dividends, Stock_Splits, Symbol)\n",
#     409     "    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)\n",
#     410     "\"\"\"\n",
#     411     "\n",
#     412     "# Process symbols in batches of 100\n",
#     413     "batch_size = 100\n",
#     414     "for i in range(0, len(symbols), batch_size):\n",
#     415     "    batch_symbols = symbols[i:i + batch_size]\n",
#     416     "    all_historical_data = pd.DataFrame()\n",
#     417     "\n",
#     418     "    for symbol in batch_symbols:\n",
#     419     "        historical_data = fetch_historical_data(symbol)\n",
#     420     "        if not historical_data.empty:\n",
#     421     "            all_historical_data = pd.concat([all_historical_data, historical_data])\n",
#     422     "\n",
#     423     "    if not all_historical_data.empty:\n",
#     424     "        records_to_insert = all_historical_data.to_records(index=False).tolist()\n",
#     425     "\n",
#     426     "        record_count = 0\n",
#     427     "        for record in records_to_insert:\n",
#     428     "            # Handle NaN values and convert them to None\n",
#     429     "            modified_record = tuple([None if pd.isna(value) else value for value in record])\n",
#     430     "\n",
#     431     "            execute_sql_query(insert_query, modified_record)\n",
#     432     "            record_count += 1\n",
#     433     "\n",
#     434     "        print(f\"Batch {i//batch_size + 1}: Inserted {record_count} records.\")\n",
#     435     "    else:\n",
#     436     "        print(f\"Batch {i//batch_size + 1}: No data to insert.\")\n",
#     437     "        \n",
#     438     "'''"
#     439    ]
#     440   },
#     441   {
#     442    "cell_type": "code",
#     443    "execution_count": null,
#     444    "id": "543e75b8-60ab-4e2c-92fc-18d09cbdb7e4",
#     445    "metadata": {},
#     446    "outputs": [],
#     447    "source": [
#     448     "'''\n",
#     449     "\n",
#     450     "The data is now added to the table. \n",
#     451     "The next step is to get company information.\n",
#     452     "This will be achieved using yfinance library method yf.info\n",
#     453     "\n",
#     454     "There is an example below.\n",
#     455     "\n",
#     456     "'''"
#     457    ]
#     458   },
#     459   {
#     460    "cell_type": "code",
#     461    "execution_count": 6,
#     462    "id": "7f37e568-9eb3-40d5-a173-cac10c3dea43",
#     463    "metadata": {
#     464     "tags": []
#     465    },
#     466    "outputs": [],
#     467    "source": [
#     468     "\n",
#     469     "\n",
#     470     "\n",
#     471     "# Using symbols gets information on company eg ticker for Apple, \n",
#     472     "symbol = \"AAPL\"  # Replace with the symbol you're interested in\n",
#     473     "ticker = yf.Ticker(symbol)\n",
#     474     "\n",
#     475     "# Access the metadata attributes\n",
#     476     "metadata = ticker.info\n",
#     477     "\n",
#     478     "\n",
#     479     "#just uncomment the print statement to see information on company.\n",
#     480     "#print (metadata)\n",
#     481     "\n"
#     482    ]
#     483   },
#     484   {
#     485    "cell_type": "code",
#     486    "execution_count": 12,
#     487    "id": "6969314d-6c98-4a31-af8a-4b0df3686be8",
#     488    "metadata": {
#     489     "tags": []
#     490    },
#     491    "outputs": [],
#     492    "source": [
#     493     "\n",
#     494     "\n",
#     495     "#The next step is to get information on companies, as tested above, yf.info method will be used to pull information from yfinance. \n"
#     496    ]
#     497   },
#     498   {
#     499    "cell_type": "code",
#     500    "execution_count": null,
#     501    "id": "db784068-722b-4aab-9b98-e2a52aee8d1f",
#     502    "metadata": {},
#     503    "outputs": [],
#     504    "source": [
#     505     "#*****************\n",
#     506     "#This code uses both function above and loops through symbols in bathc of 100 and fetches their information \n",
#     507     "#Then once information is fetched it is then inserted into the the respective table\n",
#     508     "#This code will be commented out. To avoid running by error and rewriting the entire table or causing duplication.\n",
#     509     "#SQL REFERENCE B\n",
#     510     "#Reference cell B\n",
#     511     "#*****************\n",
#     512     "'''\n",
#     513     "\n",
#     514     "with open(\"lse.txt\", \"r\", encoding='utf-8') as file:\n",
#     515     "    next(file)  # Skip the header line\n",
#     516     "    symbols = [line.split('\\t')[0].strip() for line in file]\n",
#     517     "\n",
#     518     "batch_size = 100\n",
#     519     "error_symbols = []\n",
#     520     "\n",
#     521     "for i in range(0, len(symbols), batch_size):\n",
#     522     "    batch_symbols = symbols[i:i + batch_size]\n",
#     523     "    for symbol in batch_symbols:\n",
#     524     "        info_df = fetch_info_data(symbol)\n",
#     525     "        if info_df is not None and not info_df.empty:\n",
#     526     "            for _, row in info_df.iterrows():\n",
#     527     "                insert_customer_data(row)\n",
#     528     "        else:\n",
#     529     "            error_symbols.append(symbol)  # Append symbol to error list if data fetch fails\n",
#     530     "\n",
#     531     "    print(f\"Processed batch {i // batch_size + 1}/{len(symbols) // batch_size + 1}\")\n",
#     532     "\n",
#     533     "\n",
#     534     "print(\"All data processed and inserted into source.s_customer\")\n",
#     535     "if error_symbols:\n",
#     536     "    with open('s_customer_error_symbols.csv', 'w') as f:\n",
#     537     "        for symbol in error_symbols:\n",
#     538     "            f.write(f\"{symbol}\\n\")\n",
#     539     "    print(f\"Symbols with errors written to 's_customer_error_symbols.csv'\")\n",
#     540     "\n",
#     541     "'''"
#     542    ]
#     543   },
#     544   {
#     545    "cell_type": "code",
#     546    "execution_count": null,
#     547    "id": "06186e03-bfcc-408f-84df-032007f89997",
#     548    "metadata": {},
#     549    "outputs": [],
#     550    "source": [
#     551     "'''\n",
#     552     "The above code has run and populated the table needed to be populated. \n",
#     553     "\n",
#     554     "The next step is to generate a data dimensions. \n",
#     555     "Date dimension is important in order to get STAR SCHEMA the right way for data process, therefor the below code will generate dates and related information, \n",
#     556     "such as fisical year, weekends, holidays, quarters.\n",
#     557     "\n",
#     558     "and a furthur function to insert the data into date table\n",
#     559     "\n",
#     560     "The table to store the infromation has been already generated.\n",
#     561     "\n",
#     562     "'''"
#     563    ]
#     564   },
#     565   {
#     566    "cell_type": "code",
#     567    "execution_count": 1,
#     568    "id": "72bdae13-c51a-4c1a-a60f-e002a263a74f",
#     569    "metadata": {
#     570     "tags": []
#     571    },
#     572    "outputs": [
#     573     {
#     574      "data": {
#     575       "text/plain": [
#     576        "'\\n\\ndef insert_date_dimension_row(row):\\n    query = \"\"\"\\n    INSERT INTO source.s_date \\n    (Date, Year, Quarter, Month, Week, Day, DayOfWeek, IsWeekend, IsHoliday, FiscalYear, FiscalQuarter, FiscalMonth) \\n    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)\\n    \"\"\"\\n    # Formatting the Date to string if it\\'s in datetime format\\n    date_str = row[\\'Date\\'].strftime(\\'%Y-%m-%d\\') if pd.notnull(row[\\'Date\\']) else None\\n\\n    params = (\\n        date_str, row[\\'Year\\'], row[\\'Quarter\\'], row[\\'Month\\'], row[\\'Week\\'], row[\\'Day\\'], \\n        row[\\'DayOfWeek\\'], row[\\'IsWeekend\\'], row[\\'IsHoliday\\'], row[\\'FiscalYear\\'], \\n        row[\\'FiscalQuarter\\'], row[\\'FiscalMonth\\']\\n    )\\n\\n    # Execute the SQL query\\n    execute_sql_query(query, params)\\n\\n# Generate the date dimension DataFrame\\nstart_date = datetime.date(2005, 1, 1)\\nend_date = datetime.date(2050, 12, 31)\\ndate_dimension = generate_date_dimension(start_date, end_date)\\n\\n# Iterate through each row of  DataFrame and insert it\\nfor index, row in date_dimension.iterrows():\\n    insert_date_dimension_row(row)\\n\\n'"
#     577       ]
#     578      },
#     579      "execution_count": 1,
#     580      "metadata": {},
#     581      "output_type": "execute_result"
#     582     }
#     583    ],
#     584    "source": [
#     585     "#*****************\n",
#     586     "#This code uses the function created generate_date_dimension, and the result of that function is then pushed into the database.\n",
#     587     "#This code does not need to be run regularley so will comment it out. \n",
#     588     "#SQL REFERENCE B\n",
#     589     "#Reference cell C\n",
#     590     "#*****************\n",
#     591     "\n",
#     592     "'''\n",
#     593     "\n",
#     594     "def insert_date_dimension_row(row):\n",
#     595     "    query = \"\"\"\n",
#     596     "    INSERT INTO source.s_date \n",
#     597     "    (Date, Year, Quarter, Month, Week, Day, DayOfWeek, IsWeekend, IsHoliday, FiscalYear, FiscalQuarter, FiscalMonth) \n",
#     598     "    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)\n",
#     599     "    \"\"\"\n",
#     600     "    # Formatting the Date to string if it's in datetime format\n",
#     601     "    date_str = row['Date'].strftime('%Y-%m-%d') if pd.notnull(row['Date']) else None\n",
#     602     "\n",
#     603     "    params = (\n",
#     604     "        date_str, row['Year'], row['Quarter'], row['Month'], row['Week'], row['Day'], \n",
#     605     "        row['DayOfWeek'], row['IsWeekend'], row['IsHoliday'], row['FiscalYear'], \n",
#     606     "        row['FiscalQuarter'], row['FiscalMonth']\n",
#     607     "    )\n",
#     608     "\n",
#     609     "    # Execute the SQL query\n",
#     610     "    execute_sql_query(query, params)\n",
#     611     "\n",
#     612     "# Generate the date dimension DataFrame\n",
#     613     "start_date = datetime.date(2005, 1, 1)\n",
#     614     "end_date = datetime.date(2050, 12, 31)\n",
#     615     "date_dimension = generate_date_dimension(start_date, end_date)\n",
#     616     "\n",
#     617     "# Iterate through each row of  DataFrame and insert it\n",
#     618     "for index, row in date_dimension.iterrows():\n",
#     619     "    insert_date_dimension_row(row)\n",
#     620     "\n",
#     621     "'''"
#     622    ]
#     623   },
#     624   {
#     625    "cell_type": "code",
#     626    "execution_count": 12,
#     627    "id": "cd07520a",
#     628    "metadata": {
#     629     "tags": []
#     630    },
#     631    "outputs": [],
#     632    "source": [
#     633     "stock = yf.Ticker('0JHR.L')\n",
#     634     "info = stock.history('max')\n",
#     635     "#print(info)"
#     636    ]
#     637   },
#     638   {
#     639    "cell_type": "code",
#     640    "execution_count": null,
#     641    "id": "5ec10b4e-35d0-474a-9a1d-bf232031e878",
#     642    "metadata": {},
#     643    "outputs": [],
#     644    "source": [
#     645     "'''\n",
#     646     "\n",
#     647     "Collectiong stock information of symbols that show no stock listing data.\n",
#     648     "\n",
#     649     "'''"
#     650    ]
#     651   },
#     652   {
#     653    "cell_type": "code",
#     654    "execution_count": 14,
#     655    "id": "4031268e-23f1-48f5-a810-fe0b073626c0",
#     656    "metadata": {
#     657     "tags": []
#     658    },
#     659    "outputs": [],
#     660    "source": [
#     661     "#*********************\n",
#     662     "#AND ENSURE THIS CODE REMAIN COMMENTED.\n",
#     663     "#this code is populating the missing data for some companies\n",
#     664     "#SQL REFERENCE A\n",
#     665     "#Reference cell G\n",
#     666     "#*********************\n",
#     667     "\n",
#     668     "'''\n",
#     669     "symbols = [\n",
#     670     "\"AAPL\",\n",
#     671     "\"HKLB.L\",\n",
#     672     "\"IEBB.L\",\n",
#     673     "\"LTHP.L\",\n",
#     674     "\"ICOV.L\",\n",
#     675     "\"IESP.L\",\n",
#     676     "\"MCON.L\",\n",
#     677     "\"EURO.L\",\n",
#     678     "\"FEUD.L\",\n",
#     679     "\"GAID.L\",\n",
#     680     "\"IEX5.L\",\n",
#     681     "\"PUIG.L\",\n",
#     682     "\"TFGS.L\"\n",
#     683     "]  # Example symbol, replace or extend as needed\n",
#     684     "\n",
#     685     "for symbol in symbols:\n",
#     686     "    data = fetch_missing_symbol_data(symbol)\n",
#     687     "    if not data.empty:\n",
#     688     "        records_to_insert = [\n",
#     689     "            (\n",
#     690     "                row['Date'], row['Open'], row['High'], row['Low'], row['Close'], row['Volume'],\n",
#     691     "                row['Dividends'], row['Stock Splits'], row['Symbol']\n",
#     692     "            )\n",
#     693     "            for index, row in data.iterrows()\n",
#     694     "        ]\n",
#     695     "        \n",
#     696     "        insert_query = \"\"\"\n",
#     697     "            INSERT INTO source.historical_stock_data (Date, Open, High, Low, Close, Volume, Dividends, Stock_Splits, Symbol)\n",
#     698     "            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s);\n",
#     699     "        \"\"\"\n",
#     700     "        \n",
#     701     "        # Execute SQL query for each record\n",
#     702     "        for record in records_to_insert:\n",
#     703     "            execute_sql_query(insert_query, record)\n",
#     704     "\n",
#     705     "'''\n"
#     706    ]
#     707   },
#     708   {
#     709    "cell_type": "code",
#     710    "execution_count": null,
#     711    "id": "0f4507af-7ed8-4495-a539-8964658ad55a",
#     712    "metadata": {},
#     713    "outputs": [],
#     714    "source": [
#     715     "'''\n",
#     716     "The gaps of missing data has now been completed\n",
#     717     "There is stock information available now source table. \n",
#     718     "\n",
#     719     "'''"
#     720    ]
#     721   },
#     722   {
#     723    "cell_type": "code",
#     724    "execution_count": null,
#     725    "id": "1306dd2d-d614-4491-992b-b2e45468dde3",
#     726    "metadata": {},
#     727    "outputs": [],
#     728    "source": [
#     729     "'''\n",
#     730     "\n",
#     731     "Now since the code part is complete, next thing is to fill the stock data  based on reading table from facts \"facts.dates_of_stock_info\" that will\n",
#     732     "compare the last date to todays date and if it is not the same it will fetch the data and append to source and insert it into historical stock data table.\n",
#     733     "\n",
#     734     "'''"
#     735    ]
#     736   }
#     737  ],
#     738  "metadata": {
#     739   "kernelspec": {
#     740    "display_name": "Python 3 (ipykernel)",
#     741    "language": "python",
#     742    "name": "python3"
#     743   },
#     744   "language_info": {
#     745    "codemirror_mode": {
#     746     "name": "ipython",
#     747     "version": 3
#     748    },
#     749    "file_extension": ".py",
#     750    "mimetype": "text/x-python",
#     751    "name": "python",
#     752    "nbconvert_exporter": "python",
#     753    "pygments_lexer": "ipython3",
#     754    "version": "3.11.5"
#     755   }
#     756  },
#     757  "nbformat": 4,
#     758  "nbformat_minor": 5
#     759 }
#
# File ~/anaconda3/lib/python3.11/site-packages/nbimporter.py:110, in NotebookLoader.load_module(self, fullname)
#     108         # run the code in the module
#     109         codeobj = compile(tree, filename=path, mode='exec')
# --> 110         exec(codeobj, mod.__dict__)
#     111 finally:
#     112     self.shell.user_ns = save_user_ns
#
# File ~/Desktop/Final Year project Python/Functions.ipynb:9
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 29,
#       6    "id": "bc8875e2-e912-4294-8c56-53d24f919be4",
#       7    "metadata": {
#       8     "tags": []
# ----> 9    },
#      10    "outputs": [],
#      11    "source": [
#      12     "import yfinance as yf\n",
#      13     "from datetime import datetime\n",
#      14     "import pandas as pd\n",
#      15     "import psycopg2\n",
#      16     "import configparser\n",
#      17     "import datetime\n",
#      18     "import nbimporter\n",
#      19     "from General import *\n",
#      20     "from Daily_etl import *\n",
#      21     "from SQL import *\n",
#      22     "from Connection_to_pgAdmin4 import *\n"
#      23    ]
#      24   },
#      25   {
#      26    "cell_type": "code",
#      27    "execution_count": 30,
#      28    "id": "fbe27eae-e049-4d96-b4b0-cf66bfe7b2e8",
#      29    "metadata": {},
#      30    "outputs": [
#      31     {
#      32      "data": {
#      33       "text/plain": [
#      34        "'pip install psycopg2'"
#      35       ]
#      36      },
#      37      "execution_count": 30,
#      38      "metadata": {},
#      39      "output_type": "execute_result"
#      40     }
#      41    ],
#      42    "source": [
#      43     "#installation \n",
#      44     "#by default you might not have yahoo finance/ library, or psycopg2, or  nbimporternbimporter so you may have to install one\n",
#      45     "'''pip install yfinance'''\n",
#      46     "'''pip install nbimporter'''\n",
#      47     "'''pip install psycopg2'''"
#      48    ]
#      49   },
#      50   {
#      51    "cell_type": "code",
#      52    "execution_count": 31,
#      53    "id": "16c9f4c0-895c-4ee0-abec-67c29a99f20e",
#      54    "metadata": {
#      55     "tags": []
#      56    },
#      57    "outputs": [],
#      58    "source": [
#      59     "#*********************\n",
#      60     "#This code was developed to work on the missing data that was intialy not collected with other functions. \n",
#      61     "#*********************\n",
#      62     "\n",
#      63     "\n",
#      64     "#Reference cell G\n",
#      65     "def fetch_missing_symbol_data(symbol):\n",
#      66     "    try:\n",
#      67     "        # Create a Ticker object for the given symbol\n",
#      68     "        stock = yf.Ticker(symbol)\n",
#      69     "        \n",
#      70     "        # Fetch historical data for the stock from Jan 1, 2005 until today\n",
#      71     "        hist = stock.history(start = datetime.strptime(\"2005-01-01\", \"%Y-%m-%d\"), end= datetime.now().strftime('%Y-%m-%d'))\n",
#      72     "        \n",
#      73     "         # Check if the historical data DataFrame is empty (no data returned)\n",
#      74     "        if hist.empty:\n",
#      75     "            return pd.DataFrame()# Return an empty DataFrame if no data found\n",
#      76     "        \n",
#      77     "        # Reset the index of the DataFrame which contains the dates\n",
#      78     "        hist.reset_index(inplace=True)\n",
#      79     "        \n",
#      80     "         # Add a new column to the DataFrame with the symbol name\n",
#      81     "        hist['Symbol'] = symbol\n",
#      82     "\n",
#      83     "        #the desired column order, \n",
#      84     "        #Because I was receving lots of colums that were not important, therefor i only want the the specified columns.\n",
#      85     "        desired_columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits', 'Symbol']\n",
#      86     "        return hist[desired_columns]\n",
#      87     "    \n",
#      88     "    # Print an error message with the symbol and the exception message\n",
#      89     "    except Exception as e:\n",
#      90     "        print(f\"Error fetching data for {symbol}: {str(e)}\")\n",
#      91     "        return pd.DataFrame()"
#      92    ]
#      93   },
#      94   {
#      95    "cell_type": "code",
#      96    "execution_count": 32,
#      97    "id": "590b0e94-0544-4443-af9c-809b833b08bf",
#      98    "metadata": {},
#      99    "outputs": [],
#     100    "source": [
#     101     "#***** \n",
#     102     "#Creatig function to fetch data since 2005 as a basline for the project.\n",
#     103     "\n",
#     104     "\n",
#     105     "#Reference cell A\n",
#     106     "def fetch_historical_data(symbol):\n",
#     107     "    try:\n",
#     108     "        stock = yf.Ticker(symbol)\n",
#     109     "        hist = stock.history(start=\"2005-01-01\", end=datetime.now().strftime('%Y-%m-%d'))\n",
#     110     "        if hist.empty:\n",
#     111     "            return pd.DataFrame()\n",
#     112     "        \n",
#     113     "        hist.reset_index(inplace=True)\n",
#     114     "        hist['Symbol'] = symbol\n",
#     115     "\n",
#     116     "        #the desired column order, \n",
#     117     "        #Because I was receving lots of colums that were not important, therefor i only want the the specified columns.\n",
#     118     "        desired_columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits', 'Symbol']\n",
#     119     "        return hist[desired_columns]\n",
#     120     "    except Exception as e:\n",
#     121     "        print(f\"Error fetching data for {symbol}: {str(e)}\")\n",
#     122     "        return pd.DataFrame()"
#     123    ]
#     124   },
#     125   {
#     126    "cell_type": "code",
#     127    "execution_count": 33,
#     128    "id": "641b2d17-0d3b-4e16-a941-e9615a4a95b7",
#     129    "metadata": {
#     130     "tags": []
#     131    },
#     132    "outputs": [],
#     133    "source": [
#     134     "#*******\n",
#     135     "#Creatig function to fetch Information on copanies that are listed based on symbol.\n",
#     136     "#This is slightly different because it populates information on companies.\n",
#     137     "\n",
#     138     "\n",
#     139     "#Reference cell B\n",
#     140     "def fetch_info_data(symbol):\n",
#     141     "    try:\n",
#     142     "        stock = yf.Ticker(symbol)\n",
#     143     "        info = stock.info\n",
#     144     "\n",
#     145     "        selected_columns = [\n",
#     146     "            \"address1\", \"city\", \"state\", \"zip\", \"country\", \"phone\", \"website\",\n",
#     147     "            \"industry\", \"sector\", \"sectorKey\", \"symbol\", \"longName\",\n",
#     148     "            \"fullTimeEmployees\", \"profitMargins\", \"earningsGrowth\", \"revenueGrowth\",\n",
#     149     "            \"marketCap\", \"fiftyTwoWeekHigh\", \"fiftyTwoWeekLow\", \"currency\", \"exchange\"\n",
#     150     "        ]\n",
#     151     "\n",
#     152     "        info_data = {column: info.get(column, \"N/A\") for column in selected_columns}\n",
#     153     "        return pd.DataFrame([info_data])\n",
#     154     "\n",
#     155     "    except Exception as e:\n",
#     156     "        print(f\"Error fetching data for {symbol}: {str(e)}\")\n",
#     157     "        return None"
#     158    ]
#     159   },
#     160   {
#     161    "cell_type": "code",
#     162    "execution_count": 34,
#     163    "id": "f5d345ac-549d-4ba6-845e-3b83ee9176ce",
#     164    "metadata": {
#     165     "tags": []
#     166    },
#     167    "outputs": [],
#     168    "source": [
#     169     "#*****************\n",
#     170     "#Generating date dimension\n",
#     171     "\n",
#     172     "#start_date = datetime.date(2005, 1, 1)\n",
#     173     "#end_date = datetime.date(2008, 12, 31)\n",
#     174     "\n",
#     175     "\n",
#     176     "#Reference cell C\n",
#     177     "def generate_date_dimension(start_date, end_date):\n",
#     178     "    # Generating a date range because i want to get the date upto 2050-12-31\n",
#     179     "    date_range = pd.date_range(start=start_date, end=end_date, name='Date')\n",
#     180     "    # Create DataFrame\n",
#     181     "    date_dimension = pd.DataFrame(date_range)\n",
#     182     "    # the columns to concider here are below\n",
#     183     "    date_dimension['Year'] = date_dimension['Date'].dt.year\n",
#     184     "    date_dimension['Quarter'] = date_dimension['Date'].dt.quarter\n",
#     185     "    date_dimension['Month'] = date_dimension['Date'].dt.month\n",
#     186     "    date_dimension[\"Week\"] = date_dimension[\"Date\"].dt.strftime(\"%U\")\n",
#     187     "    date_dimension['Day'] = date_dimension['Date'].dt.day\n",
#     188     "    date_dimension['DayOfWeek'] = date_dimension['Date'].dt.dayofweek\n",
#     189     "    date_dimension['IsWeekend'] = date_dimension['DayOfWeek'].isin([5, 6])\n",
#     190     "    date_dimension['IsHoliday'] = False \n",
#     191     "    date_dimension['FiscalYear'] = date_dimension['Year']  # Adjust based on fiscal year\n",
#     192     "    date_dimension['FiscalQuarter'] = date_dimension['Date'].dt.quarter  # Adjust based on fiscal quarters\n",
#     193     "    date_dimension['FiscalMonth'] = date_dimension['Date'].dt.month  # Adjust based on fiscal months\n",
#     194     "    return date_dimension\n",
#     195     "\n",
#     196     "\n",
#     197     "#to see the result of this just uncomment the print statement below"
#     198    ]
#     199   },
#     200   {
#     201    "cell_type": "code",
#     202    "execution_count": 15,
#     203    "id": "9ec03f1f-2b4d-4806-84ca-1f2ecf0a76c4",
#     204    "metadata": {
#     205     "tags": []
#     206    },
#     207    "outputs": [],
#     208    "source": [
#     209     "#start_date = datetime.date(2005, 1, 1)\n",
#     210     "#end_date = datetime.date(2008, 12, 31)\n",
#     211     "#generate_date_dimension(start_date, end_date)\n",
#     212     "\n",
#     213     "#to see the result of this just uncomment the print statement and year variable"
#     214    ]
#     215   },
#     216   {
#     217    "cell_type": "code",
#     218    "execution_count": null,
#     219    "id": "dfd3afcc-41c9-4f48-b148-ea9c2d658864",
#     220    "metadata": {},
#     221    "outputs": [],
#     222    "source": []
#     223   },
#     224   {
#     225    "cell_type": "code",
#     226    "execution_count": null,
#     227    "id": "d717ede6-0556-4358-9e7c-ebb8bb57ad18",
#     228    "metadata": {},
#     229    "outputs": [],
#     230    "source": []
#     231   },
#     232   {
#     233    "cell_type": "code",
#     234    "execution_count": null,
#     235    "id": "62eeb514-1bb4-40bc-b1e0-4101334b742e",
#     236    "metadata": {},
#     237    "outputs": [],
#     238    "source": []
#     239   }
#     240  ],
#     241  "metadata": {
#     242   "kernelspec": {
#     243    "display_name": "Python 3 (ipykernel)",
#     244    "language": "python",
#     245    "name": "python3"
#     246   },
#     247   "language_info": {
#     248    "codemirror_mode": {
#     249     "name": "ipython",
#     250     "version": 3
#     251    },
#     252    "file_extension": ".py",
#     253    "mimetype": "text/x-python",
#     254    "name": "python",
#     255    "nbconvert_exporter": "python",
#     256    "pygments_lexer": "ipython3",
#     257    "version": "3.11.5"
#     258   }
#     259  },
#     260  "nbformat": 4,
#     261  "nbformat_minor": 5
#     262 }
#
# File ~/anaconda3/lib/python3.11/site-packages/nbimporter.py:110, in NotebookLoader.load_module(self, fullname)
#     108         # run the code in the module
#     109         codeobj = compile(tree, filename=path, mode='exec')
# --> 110         exec(codeobj, mod.__dict__)
#     111 finally:
#     112     self.shell.user_ns = save_user_ns
#
# File ~/Desktop/Final Year project Python/Daily_etl.ipynb:10
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 21,
#       6    "id": "e7a011aa-fed9-4d16-96a6-9a269f8d834e",
#       7    "metadata": {
#       8     "tags": []
#       9    },
# ---> 10    "outputs": [],
#      11    "source": [
#      12     "import yfinance as yf\n",
#      13     "import pandas as pd\n",
#      14     "import psycopg2\n",
#      15     "import configparser\n",
# ...
#    3231     "    commit_transaction = \"COMMIT;\"\n",
#    3232     "\n",
#    3233     "    # Attempt to execute the SQL commands within a try-except block to handle potential errors.\n",
#    3234     "    try:\n",
#    3235     "        # Execute the SQL commands sequentially using a predefined function to manage database connection and execution.\n",
#    3236     "        # This function executes the SQL query against the database and commits or rolls back the transaction as necessary.\n",
#    3237     "        execute_sql_query(begin_transaction)\n",
#    3238     "        execute_sql_query(truncate_table)\n",
#    3239     "        execute_sql_query(insert_data)\n",
#    3240     "        execute_sql_query(commit_transaction)\n",
#    3241     "        # Notify the user that the update process was successfully completed.\n",
#    3242     "        print(\"Dates of stock info table updated successfully.\")\n",
#    3243     "    except Exception as e:\n",
#    3244     "        # If an error occurs during the execution of the SQL commands, print an error message.\n",
#    3245     "        # The message includes the specific error encountered to assist with troubleshooting.\n",
#    3246     "        print(f\"An error occurred while updating the dates of stock info table: {e}\")\n"
#    3247    ]
#    3248   },
#    3249   {
#    3250    "cell_type": "code",
#    3251    "execution_count": null,
#    3252    "id": "23c1d61c-0b21-4d09-8faa-2d14e7ecd67d",
#    3253    "metadata": {},
#    3254    "outputs": [],
#    3255    "source": []
#    3256   }
#    3257  ],
#    3258  "metadata": {
#    3259   "kernelspec": {
#    3260    "display_name": "Python 3 (ipykernel)",
#    3261    "language": "python",
#    3262    "name": "python3"
#    3263   },
#    3264   "language_info": {
#    3265    "codemirror_mode": {
#    3266     "name": "ipython",
#    3267     "version": 3
#    3268    },
#    3269    "file_extension": ".py",
#    3270    "mimetype": "text/x-python",
#    3271    "name": "python",
#    3272    "nbconvert_exporter": "python",
#    3273    "pygments_lexer": "ipython3",
#    3274    "version": "3.11.5"
#    3275   }
#    3276  },
#    3277  "nbformat": 4,
#    3278  "nbformat_minor": 5
#    3279 }
#
# File ~/anaconda3/lib/python3.11/site-packages/nbimporter.py:110, in NotebookLoader.load_module(self, fullname)
#     108         # run the code in the module
#     109         codeobj = compile(tree, filename=path, mode='exec')
# --> 110         exec(codeobj, mod.__dict__)
#     111 finally:
#     112     self.shell.user_ns = save_user_ns
#
# File ~/Desktop/Final Year project Python/SQL.ipynb:11
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 3,
#       6    "id": "8d7d8620-5ace-45d7-91c5-a88d41e6ea83",
#       7    "metadata": {
#       8     "tags": []
#       9    },
#      10    "outputs": [],
# ---> 11    "source": [
#      12     "import yfinance as yf\n",
#      13     "from datetime import datetime\n",
#      14     "import pandas as pd\n",
#      15     "import psycopg2\n",
#      16     "import configparser\n",
#      17     "import datetime\n",
#      18     "import nbimporter\n",
#      19     "from General import *\n",
#      20     "from Daily_etl import *\n",
#      21     "from Functions import *\n",
#      22     "from Connection_to_pgAdmin4 import *"
#      23    ]
#      24   },
#      25   {
#      26    "cell_type": "code",
#      27    "execution_count": 6,
#      28    "id": "93967461-5233-49eb-a75d-dce53715c7a8",
#      29    "metadata": {
#      30     "tags": []
#      31    },
#      32    "outputs": [],
#      33    "source": [
#      34     "\n",
#      35     "# Function to execute SQL queries\n",
#      36     "#SQL REFERENCE A\n",
#      37     "\n",
#      38     "\n",
#      39     "def execute_sql_query(query, params=None):\n",
#      40     "    \n",
#      41     "    # Establish a connection to the database\n",
#      42     "    connection = connect_to_database()\n",
#      43     "\n",
#      44     "    try:\n",
#      45     "        if connection:\n",
#      46     "            cursor = connection.cursor()\n",
#      47     "            \n",
#      48     "            # Execute the SQL query\n",
#      49     "            if params:\n",
#      50     "                cursor.execute(query, params)\n",
#      51     "            else:\n",
#      52     "                cursor.execute(query)\n",
#      53     "\n",
#      54     "            # If it's a SELECT query, fetch the results\n",
#      55     "            if query.strip().lower().startswith(\"select\"):\n",
#      56     "                results = cursor.fetchall()\n",
#      57     "                cursor.close()\n",
#      58     "                return results\n",
#      59     "\n",
#      60     "            # For other types of queries, commit the changes\n",
#      61     "            else:\n",
#      62     "                connection.commit()\n",
#      63     "               # print(\"Query executed successfully.\")\n",
#      64     "\n",
#      65     "    except (Exception, psycopg2.Error) as error:\n",
#      66     "        print(f\"Error: {error}\")\n",
#      67     "        if connection:\n",
#      68     "            connection.rollback()\n",
#      69     "\n",
#      70     "    finally:\n",
#      71     "        if connection:\n",
#      72     "            connection.close()\n"
#      73    ]
#      74   },
#      75   {
#      76    "cell_type": "code",
#      77    "execution_count": null,
#      78    "id": "eae8a5c0-c2fa-4ce9-8df3-311829a768f0",
#      79    "metadata": {},
#      80    "outputs": [],
#      81    "source": [
#      82     "#Creating the table to store ticker and symbol that was downloaded\n",
#      83     "#Creating first table using function.\n",
#      84     "# Define the SQL query in the 'test' variable running as test\n",
#      85     "test = \"\"\"\n",
#      86     "CREATE TABLE sou rce.ticker_and_name (\n",
#      87     "    Symbol TEXT,\n",
#      88     "    Description TEXT\n",
#      89     ");\n",
#      90     "\"\"\"\n",
#      91     "\n",
#      92     "# Execute the SQL query using the execute_sql_query function\n",
#      93     "execute_sql_query(test)"
#      94    ]
#      95   },
#      96   {
#      97    "cell_type": "code",
#      98    "execution_count": null,
#      99    "id": "fd276207-7bcd-4ba5-8c15-0561af03c743",
#     100    "metadata": {},
#     101    "outputs": [],
#     102    "source": [
#     103     "#***************\n",
#     104     "# The below function inserts company data into source schema inside table s_customer table. This table was created directly inside postgreSQL\n",
#     105     "# This will be commented out to avoid running by error and rewriting the entire table or causing duplication.\n",
#     106     "#SQL REFERENCE B\n",
#     107     "#Reference cell A\n",
#     108     "#***************\n",
#     109     "\n",
#     110     "'''\n",
#     111     "\n",
#     112     "def insert_customer_data(row):\n",
#     113     "    query = \"\"\"\n",
#     114     "    INSERT INTO source.s_customer \n",
#     115     "    (Address1, City, State, Zip, Country, Phone, Website, Industry, Sector, SectorKey, Symbol, \n",
#     116     "    Customer_Name, Full_Time_Employees, Profit_Margins, Earnings_Growth, Revenue_Growth, Market_Cap, \n",
#     117     "    Fifty_Two_Week_High, Fifty_Two_Week_Low, Currency, Exchange) \n",
#     118     "    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)\n",
#     119     "    \"\"\"\n",
#     120     "    params = (\n",
#     121     "        row['address1'] if row['address1'] != 'N/A' else None,\n",
#     122     "        row['city'] if row['city'] != 'N/A' else None,\n",
#     123     "        row['state'] if row['state'] != 'N/A' else None,\n",
#     124     "        row['zip'] if row['zip'] != 'N/A' else None,\n",
#     125     "        row['country'] if row['country'] != 'N/A' else None,\n",
#     126     "        row['phone'] if row['phone'] != 'N/A' else None,\n",
#     127     "        row['website'] if row['website'] != 'N/A' else None,\n",
#     128     "        row['industry'] if row['industry'] != 'N/A' else None,\n",
#     129     "        row['sector'] if row['sector'] != 'N/A' else None,\n",
#     130     "        row['sectorKey'] if row['sectorKey'] != 'N/A' else None,\n",
#     131     "        row['symbol'] if row['symbol'] != 'N/A' else None,\n",
#     132     "        row['longName'] if row['longName'] != 'N/A' else None,\n",
#     133     "        int(row['fullTimeEmployees']) if row['fullTimeEmployees'] != 'N/A' else None,\n",
#     134     "        float(row['profitMargins']) if row['profitMargins'] != 'N/A' else None,\n",
#     135     "        float(row['earningsGrowth']) if row['earningsGrowth'] != 'N/A' else None,\n",
#     136     "        float(row['revenueGrowth']) if row['revenueGrowth'] != 'N/A' else None,\n",
#     137     "        float(row['marketCap']) if row['marketCap'] != 'N/A' else None,\n",
#     138     "        float(row['fiftyTwoWeekHigh']) if 'fiftyTwoWeekHigh' in row and row['fiftyTwoWeekHigh'] != 'N/A' else None,\n",
#     139     "        float(row['fiftyTwoWeekLow']) if 'fiftyTwoWeekLow' in row and row['fiftyTwoWeekLow'] != 'N/A' else None,\n",
#     140     "        row['currency'] if row['currency'] != 'N/A' else None,\n",
#     141     "        row['exchange'] if row['exchange'] != 'N/A' else None\n",
#     142     "    )\n",
#     143     "    execute_sql_query(query, params)\n",
#     144     "    \n",
#     145     "'''"
#     146    ]
#     147   },
#     148   {
#     149    "cell_type": "code",
#     150    "execution_count": null,
#     151    "id": "a4ce4615-78bd-407e-b2e9-6894c786ea5f",
#     152    "metadata": {},
#     153    "outputs": [],
#     154    "source": [
#     155     "\n",
#     156     "        "
#     157    ]
#     158   },
#     159   {
#     160    "cell_type": "code",
#     161    "execution_count": null,
#     162    "id": "f6155e08-932e-4641-b8e3-2f0f27f886c4",
#     163    "metadata": {},
#     164    "outputs": [],
#     165    "source": []
#     166   },
#     167   {
#     168    "cell_type": "code",
#     169    "execution_count": null,
#     170    "id": "729de20c-8f13-489e-bb2c-ac9d8ef27396",
#     171    "metadata": {},
#     172    "outputs": [],
#     173    "source": [
#     174     "##this table has been generated by running this command  so goint to disable this as i do not want to lose the table being replaced\n",
#     175     "\n",
#     176     "'''\n",
#     177     "execute_sql_query(\"\"\"\n",
#     178     "    CREATE TABLE source.historical_stock_data (\n",
#     179     "        symbol TEXT,\n",
#     180     "        date DATE,\n",
#     181     "        open NUMERIC(10, 2),\n",
#     182     "        high NUMERIC(10, 2),\n",
#     183     "        low NUMERIC(10, 2),\n",
#     184     "        close NUMERIC(10, 2),\n",
#     185     "        volume INT,\n",
#     186     "        dividends NUMERIC(10, 2),\n",
#     187     "        stock_splits NUMERIC(10, 2)\n",
#     188     "    );\"\"\") \n",
#     189     "    \n",
#     190     "'''"
#     191    ]
#     192   }
#     193  ],
#     194  "metadata": {
#     195   "kernelspec": {
#     196    "display_name": "Python 3 (ipykernel)",
#     197    "language": "python",
#     198    "name": "python3"
#     199   },
#     200   "language_info": {
#     201    "codemirror_mode": {
#     202     "name": "ipython",
#     203     "version": 3
#     204    },
#     205    "file_extension": ".py",
#     206    "mimetype": "text/x-python",
#     207    "name": "python",
#     208    "nbconvert_exporter": "python",
#     209    "pygments_lexer": "ipython3",
#     210    "version": "3.11.5"
#     211   }
#     212  },
#     213  "nbformat": 4,
#     214  "nbformat_minor": 5
#     215 }
#
# File ~/anaconda3/lib/python3.11/site-packages/nbimporter.py:110, in NotebookLoader.load_module(self, fullname)
#     108         # run the code in the module
#     109         codeobj = compile(tree, filename=path, mode='exec')
# --> 110         exec(codeobj, mod.__dict__)
#     111 finally:
#     112     self.shell.user_ns = save_user_ns
#
# File ~/Desktop/Final Year project Python/Connection_to_pgAdmin4.ipynb:12
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 11,
#       6    "id": "6b8010f0-3b07-454f-a19c-467d8f63ece9",
#       7    "metadata": {
#       8     "tags": []
#       9    },
#      10    "outputs": [],
#      11    "source": [
# ---> 12     "import yfinance as yf\n",
#      13     "from datetime import datetime\n",
#      14     "import pandas as pd\n",
#      15     "import psycopg2\n",
#      16     "import configparser\n",
#      17     "import datetime\n",
#      18     "import nbimporter\n",
#      19     "from General import *\n",
#      20     "from Daily_etl import *\n",
#      21     "from SQL import *\n",
#      22     "from Functions import *\n",
#      23     "from PerdictiveModel1 import *"
#      24    ]
#      25   },
#      26   {
#      27    "cell_type": "code",
#      28    "execution_count": 9,
#      29    "id": "984dcd69-a9bb-4b53-81ce-268f1031839e",
#      30    "metadata": {
#      31     "tags": []
#      32    },
#      33    "outputs": [
#      34     {
#      35      "name": "stdout",
#      36      "output_type": "stream",
#      37      "text": [
#      38       "Connected to the database successfully.\n"
#      39      ]
#      40     }
#      41    ],
#      42    "source": [
#      43     "#connecting to the database\n",
#      44     "\n",
#      45     "\n",
#      46     "def connect_to_database():\n",
#      47     "     #Establish a connection to PostgreSQL database using parameters from config.ini. \n",
#      48     "        #Returns: A connection to the PostgreSQL database.\n",
#      49     "    \n",
#      50     "    try:\n",
#      51     "        # Read database credentials from the configuration file\n",
#      52     "        config = configparser.ConfigParser()\n",
#      53     "        config.read('config.ini')\n",
#      54     "\n",
#      55     "        host = config['database']['host']\n",
#      56     "        port = int(config['database']['port'])\n",
#      57     "        user = config['database']['user']\n",
#      58     "        password = config['database']['password']\n",
#      59     "        database = config['database']['database']\n",
#      60     "\n",
#      61     "        # Establish a connection to the database using the credentials from the config file\n",
#      62     "        connection = psycopg2.connect(host=host, port=port, user=user, password=password, database=database)\n",
#      63     "\n",
#      64     "        return connection\n",
#      65     "\n",
#      66     "    except (Exception, psycopg2.Error) as error:\n",
#      67     "        print(f\"Error: {error}\")\n",
#      68     "        return None\n",
#      69     "\n",
#      70     "if __name__ == \"__main__\":\n",
#      71     "    # Establish a connection to the database\n",
#      72     "    connection = connect_to_database()\n",
#      73     "\n",
#      74     "    if connection:\n",
#      75     "        print(\"Connected to the database successfully.\")\n",
#      76     "        # can continue with database operations here\n",
#      77     "\n",
#      78     "        # Close the connection when done\n",
#      79     "        connection.close()\n",
#      80     "    else:\n",
#      81     "        print(\"Failed to connect to the database.\")\n"
#      82    ]
#      83   },
#      84   {
#      85    "cell_type": "code",
#      86    "execution_count": null,
#      87    "id": "57f24fc6-aae0-47c0-b7a2-341202f9cd90",
#      88    "metadata": {},
#      89    "outputs": [],
#      90    "source": []
#      91   }
#      92  ],
#      93  "metadata": {
#      94   "kernelspec": {
#      95    "display_name": "Python 3 (ipykernel)",
#      96    "language": "python",
#      97    "name": "python3"
#      98   },
#      99   "language_info": {
#     100    "codemirror_mode": {
#     101     "name": "ipython",
#     102     "version": 3
#     103    },
#     104    "file_extension": ".py",
#     105    "mimetype": "text/x-python",
#     106    "name": "python",
#     107    "nbconvert_exporter": "python",
#     108    "pygments_lexer": "ipython3",
#     109    "version": "3.11.5"
#     110   }
#     111  },
#     112  "nbformat": 4,
#     113  "nbformat_minor": 5
#     114 }
#
# ModuleNotFoundError: No module named 'PerdictiveModel1'

# %%
#connecting to the database


def connect_to_database():
     #Establish a connection to PostgreSQL database using parameters from config.ini. 
        #Returns: A connection to the PostgreSQL database.
    
    try:
        # Read database credentials from the configuration file
        config = configparser.ConfigParser()
        config.read('config.ini')

        host = config['database']['host']
        port = int(config['database']['port'])
        user = config['database']['user']
        password = config['database']['password']
        database = config['database']['database']

        # Establish a connection to the database using the credentials from the config file
        connection = psycopg2.connect(host=host, port=port, user=user, password=password, database=database)

        return connection

    except (Exception, psycopg2.Error) as error:
        print(f"Error: {error}")
        return None

if __name__ == "__main__":
    # Establish a connection to the database
    connection = connect_to_database()

    if connection:
        print("Connected to the database successfully.")
        # can continue with database operations here

        # Close the connection when done
        connection.close()
    else:
        print("Failed to connect to the database.")
# Out:
# Connected to the database successfully.
